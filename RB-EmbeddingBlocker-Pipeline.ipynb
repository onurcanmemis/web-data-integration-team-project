# %%
from pathlib import Path
import pandas as pd
pd.set_option("display.max_columns", None) 
pd.set_option("display.max_colwidth", 150)

ROOT = Path.cwd()

DATA_DIR = ROOT / "parquet"
MLDS_DIR = ROOT / "ml-datasets"
OUTPUT_DIR = ROOT / "output"
LOGS = ROOT / "logs"
BLOCK_EVAL_DIR = OUTPUT_DIR / "blocking_evaluation"
CORR_DIR = OUTPUT_DIR / "correspondences"

BLOCK_EVAL_DIR.mkdir(parents=True, exist_ok=True)
CORR_DIR.mkdir(parents=True, exist_ok=True)

LOGS.mkdir(parents=True, exist_ok=True)
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# %%
from PyDI.io import load_parquet

metacritic = load_parquet(
    DATA_DIR / "df_metacritic.parquet",
    name="metacritic"
)

playtime = load_parquet(
    DATA_DIR / "df_playtime.parquet",
    name="playtime"
)

vgsales = load_parquet(
  DATA_DIR / "df_videogamesales.parquet",
  name="videogamesales"

)

# %%
import re, unicodedata

import re
import unicodedata

def normalize_title(text):
    if not isinstance(text, str):
        return ""
    # 1. remove accents
    text = unicodedata.normalize("NFKD", text).encode("ASCII", "ignore").decode("ASCII")
    text = text.lower().strip()
    # 2. fix possessives: "assassin's" → "assassins"
    text = re.sub(r"\'s\b", "s", text)
    # 3. remove remaining apostrophes WITHOUT adding spaces
    text = text.replace("'", "")
    # 4. replace any remaining non-alphanumeric chars with spaces
    text = re.sub(r"[^a-z0-9]+", " ", text)
    # 5. collapse whitespace
    text = re.sub(r"\s+", " ", text).strip()
    return text
metacritic["title_norm"] = metacritic["title"].apply(normalize_title)
playtime["title_norm"] = playtime["title"].apply(normalize_title)
vgsales["title_norm"] = vgsales["title"].apply(normalize_title)

# %%
from PyDI.entitymatching import (StandardBlocker,
                                 SortedNeighbourhoodBlocker,
                                 EmbeddingBlocker,
                                 RuleBasedMatcher,
                                 StringComparator,
                                 NumericComparator,
                                 EntityMatchingEvaluator)

# %%
train_p2m = load_parquet(
    MLDS_DIR / "train_PM.parquet",
    name="train_playtime_metacritic",
    add_index=False
)

test_p2m = load_parquet(
    MLDS_DIR / "test_PM.parquet",
    name="test_playtime_metacritic",
    add_index=False
)

train_p2s = load_parquet(
    MLDS_DIR / "train_PS.parquet",
    name="train_playtime_sales",
    add_index=False
)

test_p2s = load_parquet(
    MLDS_DIR / "test_PS.parquet",
    name="test_playtime_sales",
    add_index=False
)
train_p2m = train_p2m.rename(columns={"id_left": "id1", "id_right": "id2"})
test_p2m = test_p2m.rename(columns={"id_left": "id1", "id_right": "id2"})
train_p2s = train_p2s.rename(columns={"id_left": "id1", "id_right": "id2"})
test_p2s = test_p2s.rename(columns={"id_left": "id1", "id_right": "id2"})

# %%
st_blocker_p2m = StandardBlocker(
    playtime, metacritic,
    on=['title_norm'],
    batch_size=1000,
    output_dir=BLOCK_EVAL_DIR,
    id_column='id'
)

standard_candidates_p2m = st_blocker_p2m.materialize()

sn_blocker_p2m = SortedNeighbourhoodBlocker(
    playtime, metacritic,
    key='title_norm',
    window=20,
    batch_size=750,
    output_dir=BLOCK_EVAL_DIR,
    id_column='id'
)

sn_candidates_p2m = sn_blocker_p2m.materialize()


embedding_blocker_p2m = EmbeddingBlocker(
    playtime, metacritic,
    text_cols=['title_norm', 'platform','release_year'],
    model="sentence-transformers/all-MiniLM-L6-v2",
    index_backend="sklearn",
    top_k=10,
    batch_size=500,
    output_dir=BLOCK_EVAL_DIR,
    threshold=0.6,
    # Otherwise retrieves irrelevant candidates
    id_column='id'
)

embedding_candidates_p2m = embedding_blocker_p2m.materialize()

# %%
st_blocker_p2s = StandardBlocker(
    playtime, vgsales,
    on=['title_norm'],
    batch_size=1000,
    output_dir=BLOCK_EVAL_DIR,
    id_column='id'
)

standard_candidates_p2s = st_blocker_p2s.materialize()

sn_blocker_p2s = SortedNeighbourhoodBlocker(
    playtime, vgsales,
    key='title',
    window=20,
    batch_size=750,
    output_dir=BLOCK_EVAL_DIR,
    id_column='id'
)

sn_candidates_p2s = sn_blocker_p2s.materialize()




embedding_blocker_p2s = EmbeddingBlocker(
    playtime, vgsales,
    text_cols=['title_norm', 'platform','release_year'],
    model="sentence-transformers/all-MiniLM-L6-v2",
    index_backend="sklearn",
    top_k=10,
    batch_size=500,
    output_dir=BLOCK_EVAL_DIR,
    threshold=0.6,
    # Otherwise retrieves irrelevant candidates
    id_column='id'
)

embedding_candidates_p2s = embedding_blocker_p2s.materialize()

# %%
embedding_candidates_p2m.to_csv(CORR_DIR / "embedding_candidates_playtime_metacritic.csv", index=False)
embedding_candidates_p2s.to_csv(CORR_DIR / "embedding_candidates_playtime_vgsales.csv", index=False)

# %%
embedding_candidates_p2m=pd.read_csv(CORR_DIR / "embedding_candidates_playtime_metacritic.csv")
embedding_candidates_p2s=pd.read_csv(CORR_DIR / "embedding_candidates_playtime_vgsales.csv")

# %%
common_comparators= [   
    StringComparator(
        column='title_norm',
        similarity_function='cosine'
    ),
    StringComparator(
        column='platform',
        similarity_function='identity',
        preprocess=str.lower
    ),
    NumericComparator(
    column="release_year",
    method="within_range",
    max_difference=0,   # exact match only
)]
comparators_p2m = common_comparators + [
    StringComparator(
        column='developer',
        similarity_function='cosine',
        preprocess=str.lower
    )
]
comparators_p2s= common_comparators + [
    StringComparator(
        column='publisher',
        similarity_function='cosine',
        preprocess=str.lower
    )
]

# %%
matcher = RuleBasedMatcher()

correspondences_p2m,debug_p2m = matcher.match(
    df_left=playtime,
    df_right=metacritic, 
    candidates=embedding_candidates_p2m,
    comparators=comparators_p2m,
    weights=[0.5, 0.2, 0.2, 0.1],
    threshold=0.80,
    id_column='id',
    debug=True
)

correspondences_p2s,debug_p2s = matcher.match(
    df_left=playtime,
    df_right=vgsales, 
    candidates=embedding_candidates_p2s,
    comparators=comparators_p2s,
    weights=[0.5, 0.2, 0.2, 0.1],
    threshold=0.80,
    id_column='id',
    debug=True
)

# %%
cluster_analysis_dir = OUTPUT_DIR / "cluster_analysis"
EntityMatchingEvaluator.write_cluster_details(correspondences_p2m,
                                              cluster_analysis_dir/"playtime_metacritic_clusters_RB"
)
EntityMatchingEvaluator.write_cluster_details(correspondences_p2s,
                                              cluster_analysis_dir/"playtime_vgsales_clusters_RB"
)
# Out:
# PosixPath('/Users/onurcanmemis/Desktop/web-data-integration-team-project/output/cluster_analysis/playtime_vgsales_clusters_RB')

# %%
import json
import pandas as pd
from pathlib import Path

# load the clusters file
clusters = json.loads(Path("output/cluster_analysis/playtime_vgsales_clusters").read_text())

cluster_id = 1214  # change as needed

# clusters is already loaded from playtime_metacritic_clusters
cluster = next(c for c in clusters["clusters"] if c["cluster_id"] == cluster_id)

rows = []
for ent in cluster["entities"]:
    # entity string matches df["id"] exactly, e.g. "metacritic_4525"
    source = ent.split("_", 1)[0]
    df = {"metacritic": metacritic, "playtime": playtime, "sales": vgsales}.get(source)
    hit = df[df["id"] == ent].copy()
    hit.insert(0, "entity", ent)
    hit.insert(1, "source", source)
    rows.append(hit)

entity_rows = pd.concat(rows, ignore_index=True)
display(entity_rows)
display(pd.DataFrame(cluster["correspondences"]))
# Out:
#           entity    source             id                         title  \
# 0  playtime_7527  playtime  playtime_7527  Guitar Hero On Tour: Decades
# 1  playtime_7548  playtime  playtime_7548          Guitar Hero: On Tour
# 2     sales_1171     sales     sales_1171  Guitar Hero: On Tour Decades
# 3      sales_381     sales      sales_381          Guitar Hero: On Tour
#
#       platform  release_year          developer   publisher           genres  \
# 0  Nintendo DS        2008.0               None  Activision  [Music, Rhythm]
# 1  Nintendo DS        2008.0  Vicarious Visions        None  [Music, Rhythm]
# 2  Nintendo DS        2008.0                NaN  Activision           [Misc]
# 3  Nintendo DS        2008.0                NaN  Activision           [Misc]
#
#    main_story_hour  main_plus_sides_hour  completionist_hour  \
# 0             2.52                   NaN                6.22
# 1             3.00                  8.67                 NaN
# 2              NaN                   NaN                 NaN
# 3              NaN                   NaN                 NaN
#
#                     title_norm  na_sales_mil  eu_sales_mil  jp_sales_mil  \
# 0  guitar hero on tour decades           NaN           NaN           NaN
# 1          guitar hero on tour           NaN           NaN           NaN
# 2  guitar hero on tour decades          0.85          0.58          0.00
# 3          guitar hero on tour          2.11          1.01          0.01
#
#    other_sales_mil  global_sales_mil
# 0              NaN               NaN
# 1              NaN               NaN
# 2             0.16              1.58
# 3             0.35              3.48
#          entity1     entity2     score          notes
# 0  playtime_7527  sales_1171  1.000000  comparators=4
# 1  playtime_7527   sales_381  0.947214  comparators=4
# 2  playtime_7548   sales_381  0.900000  comparators=4

# %%
display(entity_rows[["id", "title", "platform", "release_year","publisher"]])
display(pd.DataFrame(cluster["correspondences"]))
# Out:
#               id                         title     platform  release_year  \
# 0  playtime_7527  Guitar Hero On Tour: Decades  Nintendo DS        2008.0
# 1  playtime_7548          Guitar Hero: On Tour  Nintendo DS        2008.0
# 2     sales_1171  Guitar Hero: On Tour Decades  Nintendo DS        2008.0
# 3      sales_381          Guitar Hero: On Tour  Nintendo DS        2008.0
#
#     publisher
# 0  Activision
# 1        None
# 2  Activision
# 3  Activision
#          entity1     entity2     score          notes
# 0  playtime_7527  sales_1171  1.000000  comparators=4
# 1  playtime_7527   sales_381  0.947214  comparators=4
# 2  playtime_7548   sales_381  0.900000  comparators=4

# %%
cluster_analysis_dir = OUTPUT_DIR / "cluster_analysis"
cluster_analysis_dir.mkdir(parents=True, exist_ok=True)
cluster_distribution_p2m = EntityMatchingEvaluator.create_cluster_size_distribution(
    correspondences=correspondences_p2m,
    out_dir=cluster_analysis_dir
)
cluster_distribution_p2s = EntityMatchingEvaluator.create_cluster_size_distribution(
    correspondences=correspondences_p2s,
    out_dir=cluster_analysis_dir
)
print(f"\n📊 Cluster Size Distribution Results (Playtime -> Metacritic):")
display(cluster_distribution_p2m)

print(f"\n📊 Cluster Size Distribution Results (Playtime -> VGSales):")
display(cluster_distribution_p2s)
# Out:
# 📊 Cluster Size Distribution Results (Playtime -> Metacritic):
#    cluster_size  frequency  percentage
# 0             2       8532   97.330595
# 1             3        173    1.973534
# 2             4         41    0.467716
# 3             5         17    0.193931
# 4             6          1    0.011408
# 5             7          2    0.022815
# 📊 Cluster Size Distribution Results (Playtime -> VGSales):
#    cluster_size  frequency  percentage
# 0             2       6016      96.256
# 1             3        171       2.736
# 2             4         47       0.752
# 3             5         11       0.176
# 4             6          2       0.032
# 5             7          1       0.016
# 6             8          2       0.032

# %%
from PyDI.entitymatching import MaximumBipartiteMatching, StableMatching

# We are using Maxmimum Bipartite Matching to refine results to 1:1 matches
clusterer = MaximumBipartiteMatching()
mbm_correspondences_p2m = clusterer.cluster(correspondences_p2m)
mbm_correspondences_p2s = clusterer.cluster(correspondences_p2s)
cluster_distribution_p2m = EntityMatchingEvaluator.create_cluster_size_distribution(
    correspondences=mbm_correspondences_p2m
)
cluster_distribution_p2s = EntityMatchingEvaluator.create_cluster_size_distribution(
    correspondences=mbm_correspondences_p2s
)
print(f"\n📊 Cluster Size Distribution Results (Playtime -> Metacritic):")
display(cluster_distribution_p2m)
print(f"\n📊 Cluster Size Distribution Results (Playtime -> VGSales):")
display(cluster_distribution_p2s)
# Out:
# 📊 Cluster Size Distribution Results (Playtime -> Metacritic):
#    cluster_size  frequency  percentage
# 0             2       8805       100.0
# 📊 Cluster Size Distribution Results (Playtime -> VGSales):
#    cluster_size  frequency  percentage
# 0             2       6310       100.0

# %%
debug_output_dir = OUTPUT_DIR / "debug_results_entity_matching"
debug_output_dir.mkdir(parents=True, exist_ok=True)

eval_results_p2m = EntityMatchingEvaluator.evaluate_matching(
    correspondences=correspondences_p2m,
    test_pairs=test_p2m,
    out_dir=debug_output_dir
)

display(eval_results_p2m)
eval_results_p2s = EntityMatchingEvaluator.evaluate_matching(
    correspondences=correspondences_p2s,
    test_pairs=test_p2s,
    out_dir=debug_output_dir
)

display(eval_results_p2s)
# Out:
# {'precision': 0.978494623655914,
#  'recall': 0.978494623655914,
#  'f1': 0.978494623655914,
#  'accuracy': 0.972972972972973,
#  'true_positives': 91,
#  'false_positives': 2,
#  'false_negatives': 2,
#  'true_negatives': 53,
#  'threshold_used': 0.0,
#  'total_correspondences': 9111,
#  'filtered_correspondences': 9111,
#  'evaluation_timestamp': '2025-11-30T16:04:57.043185',
#  'output_files': ['/Users/onurcanmemis/Desktop/web-data-integration-team-project/output/debug_results_entity_matching/matching_evaluation_summary.json',
#   '/Users/onurcanmemis/Desktop/web-data-integration-team-project/output/debug_results_entity_matching/matching_detailed_results.csv']}
# {'precision': 1.0,
#  'recall': 0.8210526315789474,
#  'f1': 0.9017341040462429,
#  'accuracy': 0.8859060402684564,
#  'true_positives': 78,
#  'false_positives': 0,
#  'false_negatives': 17,
#  'true_negatives': 54,
#  'threshold_used': 0.0,
#  'total_correspondences': 6631,
#  'filtered_correspondences': 6631,
#  'evaluation_timestamp': '2025-11-30T16:04:57.362288',
#  'output_files': ['/Users/onurcanmemis/Desktop/web-data-integration-team-project/output/debug_results_entity_matching/matching_evaluation_summary.json',
#   '/Users/onurcanmemis/Desktop/web-data-integration-team-project/output/debug_results_entity_matching/matching_detailed_results.csv']}

# %%
all_correspondences = pd.concat([mbm_correspondences_p2m, mbm_correspondences_p2s], ignore_index=True)
len(all_correspondences)
# Out:
# 15115

# %%
import numpy as np

datasets = [playtime, metacritic, vgsales]

for i, df in enumerate(datasets):
    df["genres"] = df["genres"].apply(
        lambda x: x.tolist() if isinstance(x, np.ndarray) else x
    )
    datasets[i] = df

# %%
golden_fusion_dataset=pd.read_csv(MLDS_DIR / "Golden_Fusion_Dataset.csv")
golden_fusion_dataset.head(2)
# Out:
#                                         id  title_provenance        title  \
# 0  playtime_21+sales_5232+metacritic_14639  metacritic_14639  007 Legends
# 1   playtime_4075+sales_841+metacritic_261    metacritic_261   Dead Space
#
#   platform_provenance       platform release_year_provenance  release_year  \
# 0    metacritic_14639  PlayStation 3        metacritic_14639          2012
# 1      metacritic_261  PlayStation 3          metacritic_261          2008
#
#   developer_provenance       developer publisher_provenance        publisher  \
# 0          playtime_21         Eurocom          playtime_21       Activision
# 1        playtime_4075  Visceral Games        playtime_4075  Electronic Arts
#
#                          genres_provenance  \
# 0  playtime_21+sales_5232+metacritic_14639
# 1   playtime_4075+sales_841+metacritic_261
#
#                                                                             genres  \
# 0                        ['First-Person', 'Shooter', 'Action', 'Modern', 'Arcade']
# 1  ['Horror', 'Shooter', 'Survival', 'Third-Person', 'Action', 'Sci-Fi', 'Arcade']
#
#   global_sales_mil_provenance  global_sales_mil main_story_hours_provenance  \
# 0                  sales_5232              0.36                 playtime_21
# 1                   sales_841              2.02               playtime_4075
#
#    main_story_hour main_plus_sides_hour_provenance  main_plus_sides_hour  \
# 0             6.70                     playtime_21                  7.95
# 1            11.07                   playtime_4075                 13.18
#
#   completionist_hour_provenance  completionist_hour critic_score_provenance  \
# 0                   playtime_21                9.58        metacritic_14639
# 1                 playtime_4075               20.42          metacritic_261
#
#    critic_score esrb_rating_provenance esrb_rating
# 0            41       metacritic_14639           T
# 1            88         metacritic_261           M

# %%
golden_fusion_dataset=golden_fusion_dataset.iloc[:22,:13]

# %%
from PyDI.fusion import (DataFusionStrategy,
                         DataFusionEngine,
                         longest_string,
                         union,
                         intersection,
                         prefer_higher_trust,
                         voting,
                         favour_sources)



metacritic.attrs["trust_score"] = 3
playtime.attrs["trust_score"] = 2
vgsales.attrs["trust_score"] = 1

# merge rule based correspondences
all_correspondences = pd.concat([correspondences_p2m, correspondences_p2s], ignore_index=True)

# This is the best strategy found so far
strategy = DataFusionStrategy('video_games_fusion_strategy_1')

strategy.add_attribute_fuser('title', prefer_higher_trust, trust_key="trust_score")
strategy.add_attribute_fuser('platform', voting)
strategy.add_attribute_fuser('release_year', voting)
strategy.add_attribute_fuser('genres', union)
strategy.add_attribute_fuser('developer', longest_string)
strategy.add_attribute_fuser('publisher', prefer_higher_trust, trust_key="trust_score")


strategy_2 = DataFusionStrategy('video_games_fusion_strategy_2')

strategy_2.add_attribute_fuser('title', prefer_higher_trust, trust_key="trust_score")
strategy_2.add_attribute_fuser('platform', voting)
strategy_2.add_attribute_fuser('release_year', voting)
strategy_2.add_attribute_fuser('genres', union)
strategy_2.add_attribute_fuser('developer', prefer_higher_trust, trust_key="trust_score")
strategy_2.add_attribute_fuser('publisher', prefer_higher_trust, trust_key="trust_score")



strategy_3 = DataFusionStrategy('video_games_fusion_strategy_3')

strategy_3.add_attribute_fuser('title', longest_string, trust_key="trust_score")
strategy_3.add_attribute_fuser('platform', longest_string)
strategy_3.add_attribute_fuser('release_year', voting)
strategy_3.add_attribute_fuser('genres', union)
strategy_3.add_attribute_fuser('developer', longest_string, trust_key="trust_score")
strategy_3.add_attribute_fuser('publisher', longest_string, trust_key="trust_score")



# run fusion
engine = DataFusionEngine(strategy, debug=True, debug_format='json',
                          debug_file="output/data_fusion/debug_fusion_rb_embedding_blocker.jsonl")
engine_2 = DataFusionEngine(strategy_2, debug=True, debug_format='json',
                          debug_file="output/data_fusion/debug_fusion_rb_embedding_blocker_2.jsonl")
engine_3 = DataFusionEngine(strategy_3, debug=True, debug_format='json',
                          debug_file="output/data_fusion/debug_fusion_rb_embedding_blocker_3.jsonl")

# fuse rule based matches
fused_dataset = engine.run(
    datasets=datasets,
    correspondences=all_correspondences,
    id_column="id",
    include_singletons=False,
)

fused_dataset_2= engine_2.run(
    datasets=datasets,
    correspondences=all_correspondences,
    id_column="id",
    include_singletons=False,
)
fused_dataset_3= engine_3.run(
    datasets=datasets,
    correspondences=all_correspondences,
    id_column="id",
    include_singletons=False,
)
def collect_ids_ordered(meta, prefixes=("playtime_", "sales_", "metacritic_")):
    buckets = {p: [] for p in prefixes}

    def add(s):
        if isinstance(s, str):
            for p in prefixes:
                if s.startswith(p) and s not in buckets[p]:
                    buckets[p].append(s)
                    break

    def walk(obj):
        if isinstance(obj, dict):
            for v in obj.values():
                walk(v)
        elif isinstance(obj, list):
            for v in obj:
                walk(v)
        else:
            add(obj)

    walk(meta)
    ordered = []
    for p in prefixes:
        ordered.extend(buckets[p])
    return "+".join(ordered)

# Apply to a DataFrame column of metadata dicts
fused_dataset["fusion_id"] = fused_dataset["_fusion_metadata"].apply(collect_ids_ordered)
fused_dataset["_id"]= fused_dataset["fusion_id"]
fused_dataset.drop(columns=["fusion_id"], inplace=True)

fused_dataset_2["fusion_id"] = fused_dataset_2["_fusion_metadata"].apply(collect_ids_ordered)
fused_dataset_2["_id"]= fused_dataset_2["fusion_id"]
fused_dataset_2.drop(columns=["fusion_id"], inplace=True)

fused_dataset_3["fusion_id"] = fused_dataset_3["_fusion_metadata"].apply(collect_ids_ordered)
fused_dataset_3["_id"]= fused_dataset_3["fusion_id"]
fused_dataset_3.drop(columns=["fusion_id"], inplace=True)

print(f'Fused rows: {len(fused_dataset):,}')
fused_dataset.sample(2)
# Out:
# Fused rows: 11,844
#                                    _id                     _fusion_sources  \
# 10966  playtime_24081+metacritic_13370  [metacritic_13370, playtime_24081]
# 4695   playtime_54573+metacritic_10074  [metacritic_10074, playtime_54573]
#
#       _fusion_source_datasets platform  main_story_hour  completionist_hour  \
# 10966  [metacritic, playtime]    Wii U             5.32               12.47
# 4695   [metacritic, playtime]       PC            18.60               32.25
#
#        user_score                      title  main_plus_sides_hour  \
# 10966         4.4               Mighty No. 9                  9.12
# 4695          6.2  Operencia: The Stolen Sun                 29.07
#
#        release_year  critic_score esrb_rating                id  \
# 10966        2016.0          48.0        E10+  metacritic_13370
# 4695         2019.0          76.0           T  metacritic_10074
#
#                      title_norm    publisher    developer  \
# 10966               mighty no 9  Deep Silver  Deep Silver
# 4695   operencia the stolen sun  Zen Studios  Zen Studios
#
#                                      genres  _fusion_confidence  \
# 10966    [2D, Action, Platform, Platformer]            0.730769
# 4695   [Action RPG, On-Rails, Role-Playing]            0.692308
#
#                                                                                                                                             _fusion_metadata  \
# 10966  {'platform_rule': 'voting', 'platform_sources': ['metacritic_13370', 'playtime_24081'], 'platform_inputs': [{'record_id': 'metacritic_13370', 'dat...
# 4695   {'platform_rule': 'voting', 'platform_sources': ['metacritic_10074', 'playtime_54573'], 'platform_inputs': [{'record_id': 'metacritic_10074', 'dat...
#
#        na_sales_mil  global_sales_mil  eu_sales_mil  jp_sales_mil  \
# 10966           NaN               NaN           NaN           NaN
# 4695            NaN               NaN           NaN           NaN
#
#        other_sales_mil
# 10966              NaN
# 4695               NaN

# %%
fused_dataset[["title","platform","release_year","developer","publisher","genres"]].isnull().sum()/len(fused_dataset)
# Out:
# title           0.000000
# platform        0.000000
# release_year    0.000000
# developer       0.069402
# publisher       0.054458
# genres          0.000000
# dtype: float64

# %%
from PyDI.fusion import tokenized_match, boolean_match,numeric_tolerance_match,set_equality_match,exact_match
from PyDI.fusion import DataFusionEvaluator
import numpy as np
import re, ast, numpy as np, pandas as pd


def categories_set_equal(a, b) -> bool:
    """Return True if a and b contain the same unique categories (order/type agnostic)."""
    def to_set(x):
        def items(v):
            # missing
            if v is None or (isinstance(v, float) and np.isnan(v)): return []
            # numpy array → recurse over elements
            if isinstance(v, np.ndarray): 
                out=[]; [out.extend(items(e)) for e in v.flatten()]; return out
            # python containers → recurse over elements
            if isinstance(v, (list, tuple, set)):
                out=[]; [out.extend(items(e)) for e in v]; return out
            # scalar/string: try parse stringified list; else split by delimiters
            s = str(v).strip()
            if s == "" or s.lower() in {"nan","none"}: return []
            try:
                parsed = ast.literal_eval(s)
                if isinstance(parsed, (list, tuple, set)): return items(parsed)
            except Exception:
                pass
            return [p.strip() for p in re.split(r"[|,;/]", s) if p.strip()]
        return {it.lower() for it in items(x)}
    return to_set(a) == to_set(b)

strategy.add_evaluation_function("title", exact_match)
strategy.add_evaluation_function("platform", exact_match)
strategy.add_evaluation_function("release_year", numeric_tolerance_match,tolerance=0)
strategy.add_evaluation_function("genres", categories_set_equal)
strategy.add_evaluation_function("developer", exact_match)
strategy.add_evaluation_function("publisher", exact_match)

# Create evaluator with our fusion strategy
evaluator = DataFusionEvaluator(strategy, debug=True, debug_file=OUTPUT_DIR / "data_fusion" / "debug_fusion_eval.jsonl", debug_format="json")

# Evaluate the fused results against the gold standard
print("Evaluating fusion results against gold standard...")
evaluation_results = evaluator.evaluate(
    fused_df=fused_dataset,
    fused_id_column='_id',
    gold_df=golden_fusion_dataset,
    gold_id_column='id',
)

# Display evaluation metrics
print("\nFusion Evaluation Results:")
print("=" * 40)
for metric, value in evaluation_results.items():
    if isinstance(value, float):
        print(f"  {metric}: {value:.3f}")
    else:
        print(f"  {metric}: {value}")
        
print(f"\nOverall Accuracy: {evaluation_results.get('overall_accuracy', 0):.1%}")
# Out:
# Evaluating fusion results against gold standard...
#
# Fusion Evaluation Results:
# ========================================
#   overall_accuracy: 0.924
#   macro_accuracy: 0.924
#   num_evaluated_records: 22
#   num_evaluated_attributes: 6
#   total_evaluations: 132
#   total_correct: 122
#   platform_accuracy: 1.000
#   platform_count: 22
#   title_accuracy: 0.864
#   title_count: 22
#   release_year_accuracy: 1.000
#   release_year_count: 22
#   publisher_accuracy: 0.955
#   publisher_count: 22
#   developer_accuracy: 0.727
#   developer_count: 22
#   genres_accuracy: 1.000
#   genres_count: 22
#
# Overall Accuracy: 92.4%

# %%
strategy_2.add_evaluation_function("title", exact_match)
strategy_2.add_evaluation_function("platform", exact_match)
strategy_2.add_evaluation_function("release_year", numeric_tolerance_match,tolerance=0)
strategy_2.add_evaluation_function("genres", categories_set_equal)
strategy_2.add_evaluation_function("developer", exact_match)
strategy_2.add_evaluation_function("publisher", exact_match)
# Create evaluator with our fusion strategy
evaluator = DataFusionEvaluator(strategy_2, debug=True, debug_file=OUTPUT_DIR / "data_fusion" / "debug_fusion_eval.jsonl", debug_format="json")

# Evaluate the fused results against the gold standard
print("Evaluating fusion results against gold standard...")
evaluation_results = evaluator.evaluate(
    fused_df=fused_dataset_2,
    fused_id_column='_id',
    gold_df=golden_fusion_dataset,
    gold_id_column='id',
)

# Display evaluation metrics
print("\nFusion Evaluation Results:")
print("=" * 40)
for metric, value in evaluation_results.items():
    if isinstance(value, float):
        print(f"  {metric}: {value:.3f}")
    else:
        print(f"  {metric}: {value}")
        
print(f"\nOverall Accuracy: {evaluation_results.get('overall_accuracy', 0):.1%}")
# Out:
# Evaluating fusion results against gold standard...
#
# Fusion Evaluation Results:
# ========================================
#   overall_accuracy: 0.894
#   macro_accuracy: 0.894
#   num_evaluated_records: 22
#   num_evaluated_attributes: 6
#   total_evaluations: 132
#   total_correct: 118
#   platform_accuracy: 1.000
#   platform_count: 22
#   title_accuracy: 0.864
#   title_count: 22
#   release_year_accuracy: 1.000
#   release_year_count: 22
#   publisher_accuracy: 0.955
#   publisher_count: 22
#   developer_accuracy: 0.545
#   developer_count: 22
#   genres_accuracy: 1.000
#   genres_count: 22
#
# Overall Accuracy: 89.4%

# %%
strategy_3.add_evaluation_function("title", exact_match)
strategy_3.add_evaluation_function("platform", exact_match)
strategy_3.add_evaluation_function("release_year", numeric_tolerance_match,tolerance=0)
strategy_3.add_evaluation_function("genres", categories_set_equal)
strategy_3.add_evaluation_function("developer", exact_match)
strategy_3.add_evaluation_function("publisher", exact_match)
# Create evaluator with our fusion strategy
evaluator = DataFusionEvaluator(strategy_3, debug=True, debug_file=OUTPUT_DIR / "data_fusion" / "debug_fusion_eval.jsonl", debug_format="json")

# Evaluate the fused results against the gold standard
print("Evaluating fusion results against gold standard...")
evaluation_results = evaluator.evaluate(
    fused_df=fused_dataset_3,
    fused_id_column='_id',
    gold_df=golden_fusion_dataset,
    gold_id_column='id',
)

# Display evaluation metrics
print("\nFusion Evaluation Results:")
print("=" * 40)
for metric, value in evaluation_results.items():
    if isinstance(value, float):
        print(f"  {metric}: {value:.3f}")
    else:
        print(f"  {metric}: {value}")
        
print(f"\nOverall Accuracy: {evaluation_results.get('overall_accuracy', 0):.1%}")
# Out:
# Evaluating fusion results against gold standard...
#
# Fusion Evaluation Results:
# ========================================
#   overall_accuracy: 0.788
#   macro_accuracy: 0.788
#   num_evaluated_records: 22
#   num_evaluated_attributes: 6
#   total_evaluations: 132
#   total_correct: 104
#   platform_accuracy: 1.000
#   platform_count: 22
#   title_accuracy: 0.136
#   title_count: 22
#   release_year_accuracy: 1.000
#   release_year_count: 22
#   publisher_accuracy: 0.864
#   publisher_count: 22
#   developer_accuracy: 0.727
#   developer_count: 22
#   genres_accuracy: 1.000
#   genres_count: 22
#
# Overall Accuracy: 78.8%
